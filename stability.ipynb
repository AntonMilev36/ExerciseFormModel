# %%
def hip_x_std(video_df):
    return video_df["hip_x"].std()


def knee_x_std(video_df):
    return video_df["knee_x"].std()


def shoulder_x_std(video_df):
    return video_df["shoulder_x"].std()
